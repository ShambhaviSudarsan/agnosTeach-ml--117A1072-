# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('dataset.csv')

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(data.isnull())

# %%
len(data.columns)
# Out:
# 99

# %%
data['Aspect Ratio']
data = data.drop(['Aspect Ratio'], axis=1)

# %%
df = data

# %%
data = data.drop(['Also Known As' , 'Applications'], axis=1)

# %%
data = data.drop(['Architecture'], axis=1)

# %%
data = data.drop(['Audio Features'], axis=1)

# %%
data['Audio Jack'] = '3.5 mm'
data = data.drop(['Audio Jack'], axis=1)

# %%
data['Bezel-less display'] = 'yes'

# %%
data = data.drop(['Browser'], axis=1)

# %%
len(data['Build Material'].dropna())
# Out:
# 102

# %%
data = data.drop(['Build Material'], axis=1)

# %%
x = data['Capacity'].dropna()
x.mode()
# Out:
# 0    3000 mAh
# dtype: object

# %%
def nulli(i):
    if pd.isna(i):
        return '3000 mAh'
    else:
        return i

# %%
data['Capacity']=data['Capacity'].apply(nulli)

# %%
len(data['Capacity'].dropna())
# Out:
# 355

# %%
data = data.drop(['Co-Processor'], axis=1)

# %%
data['Colours'][5] = 'Black, Blue, Gold'
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(['Display Colour'], axis=1)

# %%
data['Display Type'][5] = 'IPS LCD'
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(['Email'], axis=1)

# %%
def mem(i):
    if pd.isna(i):
        return 'Up to 128 GB'
    else:
        return i

# %%
data['Expandable Memory']=data['Expandable Memory'].apply(mem)

# %%
data['GPS'].mode()
# Out:
# 0    with A-GPS, Glonass
# dtype: object

# %%
def gps(i):
    if pd.isna(i):
        return 'with A-GPS, Glonass'
    else:
        return i

# %%
data['GPS']=data['GPS'].apply(gps)

# %%
data = data.drop(['Games'], axis=1)

# %%
data = data.drop(['HDMI'], axis=1)

# %%
data = data.drop(['Heart Rate Monitor'], axis=1)

# %%
data['Height'].mode()
# Out:
# 0    153 mm Compare Size
# dtype: object

# %%
def height(i):
    if pd.isna(i):
        return '153 mm Compare Size'
    else:
        return i

# %%
data['Height']=data['Height'].apply(height)

# %%
data = data.drop(['IRIS Scanner'], axis=1)

# %%
data['Image Resolution'].mode()
# Out:
# 0    4128 x 3096 Pixels
# dtype: object

# %%
def image(i):
    if pd.isna(i):
        return '4128 x 3096 Pixels'
    else:
        return i

# %%
data['Image Resolution']=data['Image Resolution'].apply(image)

# %%
q = data['Internal Memory'][7]
def memory(i):
    if pd.isna(i):
        return q
    else:
        return i
    
data['Internal Memory']=data['Internal Memory'].apply(memory)

# %%
data = data.drop(['Java'], axis=1)

# %%
q = 'November 1, 2018 (Official)'
def date(i):
    if pd.isna(i):
        return q
    else:
        return i
    
data['Launch Date']=data['Launch Date'].apply(date)

# %%
data['Loudspeaker'][5] = 'yes'
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(['Mobile High-Definition Link(MHL)'], axis=1)

# %%
data['Model'][5] = 'Redmi Note 6 Pro'
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(['Music'], axis=1)

# %%
data['Network'][1]
# Out:
# '4G: Available (supports Indian bands) 3G: Available, 2G: Available'

# %%
q = '4G: Available (supports Indian bands) 3G: Available, 2G: Available'
def dates(i):
    if pd.isna(i):
        return q
    else:
        return i
    
data['Network']=data['Network'].apply(dates)

# %%
data['Network Support'][5] = data['Network Support'][1]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Operating System'].mode()
# Out:
# 0    Android v8.1 (Oreo)
# dtype: object

# %%
q = 'Android v8.1 (Oreo)'
def os(i):
    if pd.isna(i):
        return q
    else:
        return i
    
data['Operating System']=data['Operating System'].apply(os)

# %%
data = data.drop(['Other Facilities'], axis=1)

# %%
q = data['Other Sensors'][1]
def other(i):
    if pd.isna(i):
        return q
    else:
        return i
    
data['Other Sensors']=data['Other Sensors'].apply(other)

# %%
data = data.drop(['Phone Book'],axis =1)

# %%
data['Pixel Density'][5] = data['Pixel Density'][0]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Processor'].mode()
# Out:
# 0    Quad core, 1.3 GHz
# dtype: object

# %%
q = data['Processor'][337]
def processor(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Processor']=data['Processor'].apply(processor)

# %%
q = data[ 'RAM'][7]
def ram(i):
    if pd.isna(i):
        return q
    else:
        return i
data['RAM']=data['RAM'].apply(ram)

# %%
q = data['Resolution'][7]
def res(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Resolution']=data['Resolution'].apply(res)

# %%
data = data.drop(['Ring Tone'],axis =1)

# %%
data['Ruggedness'] = 'Dust proof'

# %%
data['SIM 1'].mode()
# Out:
# 0    4G Bands:TD-LTE 2600(band 38) / 2300(band 40) ...
# dtype: object

# %%
data['SIM 1'][5] = data['SIM 1'][3]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
q = data['SIM 2'][326]
def sim(i):
    if pd.isna(i):
        return q
    else:
        return i
data['SIM 2']=data['SIM 2'].apply(sim)

# %%
data = data.drop(['SIM 3'],axis =1)

# %%
q = data['SIM Size'][3]
def sim2(i):
    if pd.isna(i):
        return q
    else:
        return i
data['SIM Size']=data['SIM Size'].apply(sim2)

# %%
data['SIM Slot(s)'][5] = data['SIM Slot(s)'][3]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(['SMS'],axis =1)

# %%
data['Screen Resolution'][5] = data['Screen Resolution'][327]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Screen Size'][5] = data['Screen Size'][327]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
q = data['Screen to Body Ratio (calculated)'][327]
def screen(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Screen to Body Ratio (calculated)']=data['Screen to Body Ratio (calculated)'].apply(screen)

# %%
data = data.drop(['Screen to Body Ratio (claimed by the brand)'],axis =1)

# %%
q = data['Settings'][1]
def settings(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Settings']=data['Settings'].apply(settings)

# %%
data['Shooting Modes'][1]
def shoot(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Shooting Modes']=data['Shooting Modes'].apply(shoot)

# %%
data = data.drop(['Software Based Aperture'],axis =1)

# %%
data = data.drop(['Special Features'],axis =1)

# %%
data = data.drop(['Stylus'],axis =1)

# %%
q = data['Thickness'][16]
def thick(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Thickness']=data['Thickness'].apply(thick)

# %%
q = data['Touch Screen'][1]
def touch(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Touch Screen']=data['Touch Screen'].apply(touch)

# %%
data['Type'][5] = data['Type'][1]
data['Type'][334] = data['Type'][5]
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
q = data['USB Connectivity'][1]
def usb(i):
    if pd.isna(i):
        return q
    else:
        return i
data['USB Connectivity']=data['USB Connectivity'].apply(usb)

# %%
q = 'yes'
def yes(i):
    if pd.isna(i):
        return q
    else:
        return i
data['USB OTG Support']=data['USB OTG Support'].apply(yes)

# %%
data['USB Type-C'] = data['USB Type-C'][10]

# %%
data = data.drop(['USB Type-C'],axis =1)

# %%
q = data['User Replaceable'][0]
def no(i):
    if pd.isna(i):
        return q
    else:
        return i
data['User Replaceable']=data['User Replaceable'].apply(no)

# %%
data = data.drop(['Video Player'],axis =1)

# %%
data = data.drop(['Video Recording Features'],axis =1)

# %%
q = 'yes'
def hehe(i):
    if pd.isna(i):
        return q
    else:
        return i
data['VoLTE']=data['VoLTE'].apply(hehe)

# %%
data = data.drop(['Waterproof'],axis =1)

# %%
q = data['Weight'][345]
def weight(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Weight']=data['Weight'].apply(weight)

# %%
q = data['Wi-Fi'][1]
def wifi(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Wi-Fi']=data['Wi-Fi'].apply(wifi)

# %%
q = data['Wi-Fi Features'][1]
def wififeatures(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Wi-Fi Features']=data['Wi-Fi Features'].apply(wififeatures)

# %%
q = data['Width'][23]
def width(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Width']=data['Width'].apply(width)

# %%
data = data.drop(['Wireless Charging'],axis =1)

# %%
q = data['Autofocus'][0]
def auto(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Autofocus']=data['Autofocus'].apply(auto)

# %%
q = data['Bluetooth'][1]
def blue(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Bluetooth']=data['Bluetooth'].apply(blue)

# %%
q = data['Camera Features'][0]
def camera(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Camera Features']=data['Camera Features'].apply(camera)

# %%
q = data['Chipset'][330]
def chipset(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Chipset']=data['Chipset'].apply(chipset)

# %%
data = data.drop(['Standby time'],axis =1)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['FM Radio'].dropna(),x = data['Rating'])

# %%
def impute_fm(cols):
    FMRadio = cols[0]
    Rating = cols[1]
    
    if pd.isnull(FMRadio):

        if Rating >= 4.4:
            return 'No'

        elif Rating >=4.2:
            return 'Recording option'

        elif Rating >= 4.1:
            return 'Stereo FM'
        
        elif Rating >= 4:
            return 'yes'
        
        elif Rating >=3.9:
            return 'Wireless FM'
        
        elif Rating >=3.8:
            return 'Recording option, Wireless FM'
        
        elif Rating >=3.7:
            return 'RDS'
        
        else:
            return 'RDS, Stereo FM'

    else:
        return FMRadio


data['FM Radio'] = data[['FM Radio','Rating']].apply(impute_fm,axis=1)

# %%
data['Fingerprint Sensor'].mode()
q = 'yes'
def sensor(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Fingerprint Sensor']=data['Fingerprint Sensor'].apply(sensor)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Fingerprint Sensor Position'].dropna(),x = data['Rating'])

# %%
def impute_se(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y >= 4.4:
            return 'On-screen'

        elif y >=4.2:
            return 'Side'

        elif y >= 4.1:
            return 'Rear'
        
        elif y >= 4.05:
            return 'Back'
         
        elif y>=4:
            return 'Front'
        
        elif y>=3.9:
            return 'Back'
        
        elif y>=3.7:
            return 'Front'
        
        else:
            return 'Rear'

    else:
        return x


data['Fingerprint Sensor Position'] = data[['Fingerprint Sensor Position','Rating']].apply(impute_se,axis=1)

# %%
data['Flash'].dropna()
q = 'LED Flash'
def yo(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Flash']=data['Flash'].apply(yo)

# %%
q = data['Graphics'][1]
def graphics(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Graphics']=data['Graphics'].apply(graphics)

# %%
data['NFC'].dropna()
plt.figure(figsize=(5, 7))
sns.boxplot(y = data['NFC'].dropna(),x = data['Rating'])

# %%
def impute_NFC(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y >= 4.2:
            return 'yes'

        elif y >=4.0:
            return 'No'

        elif y >= 3.2:
            return 'No'
        
        else:
            return 'yes'

    else:
        return x


data['NFC'] = data[['NFC','Rating']].apply(impute_NFC,axis=1)

# %%
data['Optical Image Stabilisation'].dropna()
plt.figure(figsize=(5, 7))
sns.boxplot(y = data['Optical Image Stabilisation'].dropna(),x = data['Rating'])

# %%
def impute_image(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y == 4.5:
            return 'Dual optical image stabilization'

        elif y >=4.0:
            return 'yes'
        
        else:
            return 'No'

    else:
        return x


data['Optical Image Stabilisation'] = data[['Optical Image Stabilisation','Rating']].apply(impute_image,axis=1)

# %%
data['Physical Aperture'].dropna()
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Physical Aperture'].dropna(),x = data['Rating'])

# %%
def impute_phy(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):
        
        if y>=4.6:
            return 'F2.0'
        
        if y >= 4.4:
            return 'F1.7'

        elif y >=4.3:
            return 'F1.8'
        
        elif y> 4.2:
            return 'F2.2'
        
        elif y> 4.1:
            return 'F2.1'
        
        elif y>4.09:
            return 'F2'
        
        elif y> 4.05:
            return 'F1.9'
        
        elif y> 4:
            return 'F2.4'
        
        elif y> 3.6:
            return 'F2.8'
        
        else:
            return 'F2.2'

    else:
        return x


data['Physical Aperture'] = data[['Physical Aperture','Rating']].apply(impute_phy,axis=1)

# %%
data['Quick Charging'].dropna()
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Quick Charging'].dropna(),x = data['Rating'])

# %%
def impute_image(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y >= 4.5:
            return 'Quick, v3.0'

        elif y >=4.0:
            return 'No'
        
        elif y>=3.5:
            return 'Turbo'
        else:
            return 'Quick, v2.0'

    else:
        return x


data['Quick Charging'] = data[['Quick Charging','Rating']].apply(impute_image,axis=1)

# %%
data = data.drop(['SAR Value'],axis =1)

# %%
data['Screen Protection'].dropna()
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Screen Protection'].dropna(),x = data['Rating'])

# %%
def impute_i(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y >= 4.5:
            return 'Corning Gorilla Glass v5'

        elif y >=4.3:
            return 'yes'
        
        elif y>=4.2:
            return 'Corning Gorilla Glass v4,Scratch-resistant glass'
        
        elif y >=4.1:
            return 'Corning Gorilla Glass v4'
        
        elif y >=3.9:
            return 'Corning Gorilla Glass v3'
        
        elif y>=3.8:
            return 'Corning Gorilla Glass v4,Scratch-resistant glass'
        
        else:
            return 'Corning Gorilla Glass v3'

    else:
        return x


data['Screen Protection'] = data[['Screen Protection','Rating']].apply(impute_i,axis=1)

# %%
q = data['Video Recording'][1]
def bl(i):
    if pd.isna(i):
        return q
    else:
        return i
data['Video Recording']=data['Video Recording'].apply(bl)

# %%
data['Aspect Ratio'].dropna()
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Aspect Ratio'].dropna(),x = data['Rating'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Aspect Ratio'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-547-e708d947c68e> in <module>
# ----> 1 data['Aspect Ratio'].dropna()
# ...

# %%
def impute_a(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y > 4.6:
            return '19.3:9'

        elif y > 4.5:
            return '18.7:9'
        
        elif y>4.4:
            return '19.5:9'
        
        elif y >=4.3:
            return '19:9'
        
        elif y >=4.2:
            return '18.5:9'
        
        elif y>=4:
            return '18:9'
        
        elif y>=3.8:
            return '16:9'
        
        else:
            return '18:9'

    else:
        return x


data['Aspect Ratio'] = data[['Aspect Ratio','Rating']].apply(impute_a,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-548-fcb8eba8f0ac> in <module>
#      33
#      34
# ---> 35 data['Aspect Ratio'] = data[['Aspect Ratio','Rating']].apply(impute_a,axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
data['Brand'][5] = 'Samsung'
# Out:
# /Users/shambhavi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(['User Available Storage'],axis =1)

# %%
data = data.drop(['TalkTime'],axis =1)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Sensor'].dropna(),x = data['Rating'])

# %%
def impute_abc(cols):
    x = cols[0]
    y = cols[1]
    
    if pd.isnull(x):

        if y >= 4.7:
            return 'Exmor-R CMOS'

        elif y > 4.49:
            return 'BSI Sensor'
        
        elif y>4.4:
            return 'Exmor RS'
        
        elif y >=4.35:
            return 'CMOS image sensor, Exmor-RS CMOS Sensor'
    
        elif y >=4.3:
            return 'Exmor-RS CMOS Sensor'
        
        elif y>=4.2:
            return 'CMOS'
        
        elif y>=4.1:
            return 'PureCel Sensor'
        
        elif y>=4:
            return 'Back-illuminated sensor (BSI)'
        
        elif y>=3.7:
            return 'Exmor-R CMOS'
        
        else:
            return 'BSI Sensor'

    else:
        return x


data['Sensor'] = data[['Sensor','Rating']].apply(impute_abc,axis=1)

# %%
data['Custom UI']
plt.figure(figsize=(15, 10))
sns.boxplot(y = data['Custom UI'].dropna(),x = data['Rating'])

# %%
data = data.drop(['Custom UI'],axis =1)

# %%
def remove(i):
    if(i>3.5):
        return 1
    else:
        return 0

# %%
data['Rating']=data['Rating'].apply(remove)

# %%
x = data.iloc[:,:64]
x.columns
# Out:
# Index(['PhoneId', 'Autofocus', 'Bezel-less display', 'Bluetooth', 'Brand',
#        'Camera Features', 'Capacity', 'Chipset', 'Colours', 'Display Type',
#        'Expandable Memory', 'FM Radio', 'Fingerprint Sensor',
#        'Fingerprint Sensor Position', 'Flash', 'GPS', 'Graphics', 'Height',
#        'Image Resolution', 'Internal Memory', 'Launch Date', 'Loudspeaker',
#        'Model', 'NFC', 'Network', 'Network Support', 'Operating System',
#        'Optical Image Stabilisation', 'Other Sensors', 'Physical Aperture',
#        'Pixel Density', 'Processor', 'Quick Charging', 'RAM', 'Rating Count',
#        'Resolution', 'Review Count', 'Ruggedness', 'SIM 1', 'SIM 2',
#        'SIM Size', 'SIM Slot(s)', 'Screen Protection', 'Screen Resolution',
#        'Screen Size', 'Screen to Body Ratio (calculated)', 'Sensor',
#        'Settings', 'Shooting Modes', 'Thickness', 'Touch Screen', 'Type',
#        'USB Connectivity', 'USB OTG Support', 'User Replaceable',
# ...

# %%
y = data['Rating']

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
categorical_feature_mask = x.dtypes==object
categorical_cols = x.columns[categorical_feature_mask].tolist()

# %%
x[categorical_cols] = x[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
q = x[categorical_cols].head(355)

# %%
q
# Out:
#      Autofocus  Bezel-less display  Bluetooth  Brand  Camera Features  \
# 0            6                   0          8     44               25
# 1            6                   0          7     36                5
# 2           12                   0          7     36                5
# 3            5                   0          8     38               25
# 4            6                   0          7      9               25
# 5            6                   0          7     38               25
# 6            6                   0          8     43               25
# 7            6                   0          7     44               14
# 8            6                   0          7     44               25
# 9           12                   0          7     31               25
# 10           1                   0          8     45               25
# 11           6                   0          8     32               29
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(q, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 70)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=70, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[  3  10]
#  [  0 105]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.23      0.38        13
#            1       0.91      1.00      0.95       105
#
#    micro avg       0.92      0.92      0.92       118
#    macro avg       0.96      0.62      0.66       118
# weighted avg       0.92      0.92      0.89       118
